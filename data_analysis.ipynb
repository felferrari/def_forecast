# %%
from cfg import config
import numpy as np
from utils.ops import load_ml_image, load_sb_image
import matplotlib.pyplot as plt

# %%
band_first = 34
band_last = band_first + 24

# %%
qd_paths_dict = config.path_to_data['def_data']
def_data = load_ml_image(qd_paths_dict)[:,:,band_first:band_last]
def_data = def_data.flatten()

def_data = def_data[def_data>0]

# %%
def_data.shape
# Out:
# (626,)

# %%
plt.hist(def_data, bins = 100)
plt.show()
