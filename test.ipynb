# %%
import mlflow
logged_model = 'runs:/75200031d53f40aab13efac77f7bf8b4/model'
mlflow.set_tracking_uri('file:./experiments/ml-runs')
# Load model as a PyFuncModel.
loaded_model = mlflow.pytorch.load_model(logged_model)

# %%
loaded_model
# Out:
# ModelModule(
#   (model): Resunet(
#     (encoder): ResUnetEncoder(
#       (first_res_block): Sequential(
#         (0): Conv2d(2, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#         (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU()
#         (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), padding_mode=reflect)
#       )
#       (first_res_cov): Conv2d(2, 32, kernel_size=(1, 1), stride=(1, 1))
#       (blocks): ModuleList(
#         (0): ResidualBlock(
#           (res_block): Sequential(
#             (0): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (1): ReLU()
#             (2): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#             (3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (4): ReLU()
# ...
