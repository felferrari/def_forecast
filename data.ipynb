# %%
from utils.ops import load_sb_image
from pathlib import Path
import matplotlib.pyplot as plt

# %%
path = Path(r'D:\Ferrari\Projects\deforestation-forescast\data\INPE')

a = load_sb_image(path / 'amz_25km_apa.tif')

# %%
plt.imshow(a)

# %%
plt.imshow(a[10000:20000, 10000:20000])

# %%
x_min = 2795368.0772499949671328
y_min = 8138773.4245220422744751
x_max = 6195368.0772499945014715
y_max = 10588773.4245220422744751

# %%
print(f'{x_min - 12500} {y_min - 12500} {x_max + 12500} {y_max + 12500} ')
# Out:
# 2782868.077249995 8126273.424522042 6207868.0772499945 10601273.424522042

# %%
print(f'{x_min} {y_min} {x_max} {y_max} ')
# Out:
# 2795368.077249995 8138773.424522042 6195368.0772499945 10588773.424522042
